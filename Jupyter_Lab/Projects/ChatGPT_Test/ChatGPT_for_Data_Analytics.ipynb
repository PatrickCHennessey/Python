# %%
import pandas as pd

# Create a test DataFrame using a dictionary
test = {
    'Column A': [1, 2, 3, 4],
    'Column B': ['A', 'B', 'C', 'D'],
    'Column C': [True, False, True, False]
}

df = pd.DataFrame(test)

# Display the DataFrame
df
# Out:
#    Column A Column B  Column C
# 0         1        A      True
# 1         2        B     False
# 2         3        C      True
# 3         4        D     False

# %%
# Replace 'file_path.csv' with the path to your CSV file
file_path = 'C:/Users/Admin/Desktop/DADS/Data Sets/Kaggle/gsearch_jobs_cleaned.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

# %%
# Display the DataFrame
df
# Out:
#        Unnamed: 0  index                                              title  \
# 0               0      0                                       Data Analyst
# 1               1      1  Junior Data Analyst/Scientist Role - Contract ...
# 2               2      2                                       Data Analyst
# 3               3      3                                       Data Analyst
# 4               4      4                                       Data Analyst
# ...           ...    ...                                                ...
# 42203       42203    579                     Marketing Data & BI Analyst II
# 42204       42204    580                                  Lead-Data Analyst
# 42205       42205    581                                  Lead-Data Analyst
# 42206       42206    582                                  Lead-Data Analyst
# 42207       42207    583  Institutional Credit Management - Lending Data...
#
#            company_name                location                    via  \
# 0               Chloeta    Oklahoma City, OK          via ZipRecruiter
# 1                Upwork               Anywhere              via Upwork
# 2                   ATC        United States              via LinkedIn
# 3            Guidehouse           Topeka, KS                 via Nexxt
# 4      AnMed Health LLC               Anywhere            via LinkedIn
# ...                 ...                     ...                    ...
# 42203      EDWARD JONES           Houstonia, MO  via My ArkLaMiss Jobs
# 42204      EDWARD JONES          Marshfield, MO  via My ArkLaMiss Jobs
# 42205      EDWARD JONES          High Point, MO  via My ArkLaMiss Jobs
# 42206      EDWARD JONES             Calhoun, MO  via My ArkLaMiss Jobs
# 42207              Citi           United States  via My ArkLaMiss Jobs
#
#                                              description  \
# 0      Job Summary: The Data Analyst oversees data pr...
# 1      Company\n\nThe TAC Index provides independent,...
# 2      Job Title: Entry Level Business Analyst / Prod...
# 3      Job Family :\n\nData Science & Analysis (Digit...
# 4      AnMed is a dynamic, comprehensive health syste...
# ...                                                  ...
# 42203  At Edward Jones, we help clients achieve their...
# 42204  At Edward Jones, we help clients achieve their...
# 42205  At Edward Jones, we help clients achieve their...
# 42206  At Edward Jones, we help clients achieve their...
# 42207  The Institutional Credit Management (ICM) grou...
#
#                                               extensions  \
# 0      ['21 hours ago', 'Full-time', 'Health insuranc...
# 1      ['17 hours ago', 'Work from home', 'Contractor...
# 2      ['12 hours ago', 'Full-time', 'Health insurance']
# 3      ['10 hours ago', 'Full-time', 'Health insuranc...
# 4      ['18 hours ago', 'Work from home', 'Part-time'...
# ...                                                  ...
# 42203  ['23 hours ago', '76,798–130,764 a year', 'Ful...
# 42204  ['23 hours ago', '106,916–182,047 a year', 'Fu...
# 42205  ['23 hours ago', '106,916–182,047 a year', 'Fu...
# 42206  ['23 hours ago', '106,916–182,047 a year', 'Fu...
# 42207  ['24 hours ago', '105,850–158,780 a year', 'Fu...
#
#                                                   job_id  \
# 0      eyJqb2JfdGl0bGUiOiJEYXRhIEFuYWx5c3QiLCJodGlkb2...
# 1      eyJqb2JfdGl0bGUiOiJKdW5pb3IgRGF0YSBBbmFseXN0L1...
# 2      eyJqb2JfdGl0bGUiOiJEYXRhIEFuYWx5c3QiLCJodGlkb2...
# 3      eyJqb2JfdGl0bGUiOiJEYXRhIEFuYWx5c3QiLCJodGlkb2...
# 4      eyJqb2JfdGl0bGUiOiJEYXRhIEFuYWx5c3QiLCJodGlkb2...
# ...                                                  ...
# 42203  eyJqb2JfdGl0bGUiOiJNYXJrZXRpbmcgRGF0YSBcdTAwMj...
# 42204  eyJqb2JfdGl0bGUiOiJMZWFkLURhdGEgQW5hbHlzdCIsIm...
# 42205  eyJqb2JfdGl0bGUiOiJMZWFkLURhdGEgQW5hbHlzdCIsIm...
# 42206  eyJqb2JfdGl0bGUiOiJMZWFkLURhdGEgQW5hbHlzdCIsIm...
# 42207  eyJqb2JfdGl0bGUiOiJJbnN0aXR1dGlvbmFsIENyZWRpdC...
#
#                                                thumbnail  ... commute_time  \
# 0                                                    NaN  ...          NaN
# 1                                                    NaN  ...          NaN
# 2      https://encrypted-tbn0.gstatic.com/images?q=tb...  ...          NaN
# 3      https://encrypted-tbn0.gstatic.com/images?q=tb...  ...          NaN
# 4                                                    NaN  ...          NaN
# ...                                                  ...  ...          ...
# 42203                                                NaN  ...          NaN
# 42204                                                NaN  ...          NaN
# 42205                                                NaN  ...          NaN
# 42206                                                NaN  ...          NaN
# 42207  https://encrypted-tbn0.gstatic.com/images?q=tb...  ...          NaN
#
#           salary_pay salary_rate salary_avg salary_min salary_max  \
# 0                NaN         NaN        NaN        NaN        NaN
# 1                NaN         NaN        NaN        NaN        NaN
# 2                NaN         NaN        NaN        NaN        NaN
# 3                NaN         NaN        NaN        NaN        NaN
# 4                NaN         NaN        NaN        NaN        NaN
# ...              ...         ...        ...        ...        ...
# 42203   76798–130764      a year   103781.0    76798.0   130764.0
# 42204  106916–182047      a year   144481.5   106916.0   182047.0
# 42205  106916–182047      a year   144481.5   106916.0   182047.0
# 42206  106916–182047      a year   144481.5   106916.0   182047.0
# 42207  105850–158780      a year   132315.0   105850.0   158780.0
#
#       salary_hourly  salary_yearly salary_standardized  \
# 0               NaN            NaN                 NaN
# 1               NaN            NaN                 NaN
# 2               NaN            NaN                 NaN
# 3               NaN            NaN                 NaN
# 4               NaN            NaN                 NaN
# ...             ...            ...                 ...
# 42203           NaN       103781.0            103781.0
# 42204           NaN       144481.5            144481.5
# 42205           NaN       144481.5            144481.5
# 42206           NaN       144481.5            144481.5
# 42207           NaN       132315.0            132315.0
#
#                                       description_tokens
# 0                                        ['r', 'python']
# 1      ['matplotlib', 'pandas', 'mongodb', 'mysql', '...
# 2                                                     []
# 3      ['excel', 'word', 'powerpoint', 'outlook', 'ql...
# 4                                                     []
# ...                                                  ...
# 42203  ['excel', 'snowflake', 'sql', 'r', 'tableau', ...
# 42204                                                 []
# 42205                                                 []
# 42206                                                 []
# 42207                              ['tableau', 'cognos']
#
# [42208 rows x 27 columns]
