# %%
# Table Extraction: Extract Tables From Websites
# Out:
#   File "<ipython-input-53-8eb25b1e7577>", line 3
#     conda update --all
#           ^
# SyntaxError: invalid syntax

# %%
# Step 1: Import required libraies 
import pandas as pd
import requests

# %%
# Step 2: Have script read the desired webpage
requests.get('https://example.com', verify=False) # Ignores SSL Certification Error
pd.read_html('https://en.wikipedia.org/wiki/List_of_Futurama_episodes#Season_1_(1999)')
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# ~\anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1349             try:
# -> 1350                 h.request(req.get_method(), req.selector, req.data, headers,
#    1351                           encode_chunked=req.has_header('Transfer-encoding'))
#
# ~\anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1254         """Send a complete request to the server."""
# -> 1255         self._send_request(method, url, body, headers, encode_chunked)
#    1256
#
# ~\anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1300             body = _encode(body, 'body')
# -> 1301         self.endheaders(body, encode_chunked=encode_chunked)
#    1302
#
# ...

# %%
futurama = pd.read_html('https://en.wikipedia.org/wiki/List_of_Futurama_episodes#Season_1_(1999)')
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# ~\anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1349             try:
# -> 1350                 h.request(req.get_method(), req.selector, req.data, headers,
#    1351                           encode_chunked=req.has_header('Transfer-encoding'))
#
# ~\anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1254         """Send a complete request to the server."""
# -> 1255         self._send_request(method, url, body, headers, encode_chunked)
#    1256
#
# ~\anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1300             body = _encode(body, 'body')
# -> 1301         self.endheaders(body, encode_chunked=encode_chunked)
#    1302
#
# ...

# %%
# Display number of tables in webpage
len(futurama)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-9ef64d3f3baf> in <module>
#       1 # Display number of tables in webpage
# ----> 2 len(futurama)
#
# NameError: name 'futurama' is not defined

# %%
# Display first table

futurama[1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-66e15c29a6e5> in <module>
#       1 # Display first table
#       2
# ----> 3 futurama[1]
#
# NameError: name 'futurama' is not defined
