# %%
# Table Extraction: Extract Tables From Websites

# %%
# Step 1: Import required libraies 
import pandas as pd
import requests
import ssl

# %%
# Temporarily remove SSL Verification Error.
ssl._create_default_https_context = ssl._create_unverified_context

# %%
# Assign variable to URL that tables are located within
url = 'https://en.wikipedia.org/wiki/List_of_Futurama_episodes#Season_1_(1999)'

# %%
# Assign variable to read function
futurama = pd.read_html(url)

# %%
# Print previously assigned variable to have Jupyter Lab execute the read function
print(futurama)
# Out:
# [   Season Episodes              Originally aired                      \
#    Season Episodes Episodes.1        First aired          Last aired
# 0       1       13         13     March 28, 1999   November 14, 1999
# 1       2       19         19  November 21, 1999    December 3, 2000
# 2       3       22         22   January 21, 2001    December 8, 2002
# 3       4       18         18  February 10, 2002     August 10, 2003
# 4       5       16         16     March 23, 2008     August 30, 2009
# 5       6       26         13      June 24, 2010   November 21, 2010
# 6       6       26         13      June 23, 2011   September 8, 2011
# 7       7       26         13      June 20, 2012     August 29, 2012
# 8       7       26         13      June 19, 2013   September 4, 2013
# 9   8[10]       20         10      July 24, 2023  September 25, 2023
# 10  8[10]       20         10                TBA                 TBA
#
#
#            Network
# 0              Fox
# 1              Fox
# ...

# %%
# Display number of tables in webpage
len(futurama)
# Out:
# 14

# %%
# Display first table
futurama[1]
# Out:
#     No. overall  No. in season                           Title  \
# 0             1              1              "Space Pilot 3000"
# 1             2              2         "The Series Has Landed"
# 2             3              3                   "I, Roommate"
# 3             4              4  "Love's Labours Lost in Space"
# 4             5              5          "Fear of a Bot Planet"
# 5             6              6          "A Fishful of Dollars"
# 6             7              7                 "My Three Suns"
# 7             8              8        "A Big Piece of Garbage"
# 8             9              9          "Hell Is Other Robots"
# 9            10             10          "A Flight to Remember"
# 10           11             11               "Mars University"
# 11           12             12            "When Aliens Attack"
# 12           13             13     "Fry and the Slurm Factory"
#
#                       Directed by                      Written by  \
# ...
